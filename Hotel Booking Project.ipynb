# %% [markdown]
# # Hotel booking Analysis

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import chardet

# %%
df = pd.read_csv("C:/Users/Madhuri/Downloads/archive (32).zip")
df
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
df.tail()
# Out:
#       Booking_ID  number of adults  number of children  \
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights type of meal  \
# 36280                         0                      2  Meal Plan 2
# 36281                         1                      3  Meal Plan 1
# 36282                         1                      3  Meal Plan 1
# 36283                         0                      4  Meal Plan 1
# 36284                         0                      5  Meal Plan 1
#
#        car parking space    room type  lead time market segment type  \
# 36280                  0  Room_Type 1        346              Online
# 36281                  0  Room_Type 1         34              Online
# ...

# %%
df.shape
# Out:
# (36285, 17)

# %%
df.columns
# Out:
# Index(['Booking_ID', 'number of adults', 'number of children',
#        'number of weekend nights', 'number of week nights', 'type of meal',
#        'car parking space', 'room type', 'lead time', 'market segment type',
#        'repeated', 'P-C', 'P-not-C', 'average price', 'special requests',
#        'date of reservation', 'booking status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
df.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
df.isnull().sum()*100
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
df.nunique()
# Out:
# Booking_ID                  36285
# number of adults                5
# number of children              6
# number of weekend nights        8
# number of week nights          18
# type of meal                    4
# car parking space               2
# room type                       7
# lead time                     352
# market segment type             5
# repeated                        2
# P-C                             9
# P-not-C                        59
# average price                3930
# special requests                6
# date of reservation           553
# booking status                  2
# dtype: int64

# %%
df[df['date of reservation'].str.contains('^(?!\d{1,2}/\d{1,2}/\d{4}$).*$')]['date of reservation']
# Out:
# 2626     2018-2-29
# 3677     2018-2-29
# 5600     2018-2-29
# 6343     2018-2-29
# 7648     2018-2-29
# 8000     2018-2-29
# 8989     2018-2-29
# 9153     2018-2-29
# 9245     2018-2-29
# 9664     2018-2-29
# 9934     2018-2-29
# 10593    2018-2-29
# 10652    2018-2-29
# 10747    2018-2-29
# 11881    2018-2-29
# 13958    2018-2-29
# 14304    2018-2-29
# 15363    2018-2-29
# 15438    2018-2-29
# 17202    2018-2-29
# 18380    2018-2-29
# 18534    2018-2-29
# 18680    2018-2-29
# 19013    2018-2-29
# 20419    2018-2-29
# 21674    2018-2-29
# 21688    2018-2-29
# 26108    2018-2-29
# 27559    2018-2-29
# 27928    2018-2-29
# 30552    2018-2-29
# 30616    2018-2-29
# 30632    2018-2-29
# 30839    2018-2-29
# 32041    2018-2-29
# 34638    2018-2-29
# 35481    2018-2-29
# Name: date of reservation, dtype: object

# %%
# Since 29 is not in February(not a leap year) so we will change it to 28
error_dates_index = df[df['date of reservation']=='2018-2-29'].index

df.iloc[error_dates_index,15] =  '2/28/2018'

# %%
# Changing datatype to Datetime
df['date of reservation'] = pd.to_datetime(df['date of reservation'])

# %%
df.drop(columns='Booking_ID',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          36285 non-null  int64
#  1   number of children        36285 non-null  int64
#  2   number of weekend nights  36285 non-null  int64
#  3   number of week nights     36285 non-null  int64
#  4   type of meal              36285 non-null  object
#  5   car parking space         36285 non-null  int64
#  6   room type                 36285 non-null  object
#  7   lead time                 36285 non-null  int64
#  8   market segment type       36285 non-null  object
#  9   repeated                  36285 non-null  int64
#  10  P-C                       36285 non-null  int64
#  11  P-not-C                   36285 non-null  int64
#  12  average price             36285 non-null  float64
#  13  special requests          36285 non-null  int64
# ...

# %%
df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price  \
# ...

# %%
df['date of reservation']= pd.to_datetime(df['date of reservation'])

# %% [markdown]
# # Univariate Analysis

# %%
# Summary Statistics
summary_stats = df.describe()
print(summary_stats)
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
# std            0.518813            0.402704                  0.870590
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# min                 0.000000           0.000000      0.000000      0.000000
# ...

# %%
fig, axes = plt.subplots(figsize=(12, 4), ncols=2)
sns.kdeplot(df['average price'], ax=axes[0])
axes[0].set_title('Distribution of Average Price')
axes[0].set_xlabel('Average Price')

# Plot KDE for 'lead time'
sns.kdeplot(df['lead time'], ax=axes[1])
axes[1].set_title('Distribution of Lead Time')
axes[1].set_xlabel('Lead Time')
axes[1].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(figsize=(12, 6), ncols=2)

# Plot Boxplot for 'average price'
sns.boxplot(y=df['average price'], ax=axes[0])
axes[0].set_title('Box Plot of Average Price')
axes[0].set_ylabel('Average Price')

# Plot Boxplot for 'lead time'
sns.boxplot(y=df['lead time'], ax=axes[1])
axes[1].set_title('Box Plot of Lead Time')
axes[1].set_ylabel('Lead Time')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(df['number of adults'].value_counts(), 
       labels=df['number of adults'].value_counts().index, 
       autopct='%0.1f%%')
ax.set_title('Number of Adults')

plt.show()

# %%
df['number of adults'].value_counts()
# Out:
# number of adults
# 2    26110
# 1     7702
# 3     2318
# 0      139
# 4       16
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(df['number of children'].value_counts(), 
       labels=df['number of children'].value_counts().index, 
       autopct='%0.1f%%')
ax.set_title('number of children')

plt.show()

# %%
df['number of children'].value_counts()
# Out:
# number of children
# 0     33583
# 1      1622
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(df['number of weekend nights'].value_counts(), 
       labels=df['number of weekend nights'].value_counts().index, 
       autopct='%0.1f%%')
ax.set_title('number of weekend nights')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(df['number of week nights'].value_counts(), 
       labels=df['number of week nights'].value_counts().index, 
       autopct='%0.1f%%')
ax.set_title('number of week nights')

plt.show()

# %%
fig , axes = plt.subplots(figsize=(6,8),nrows=3,ncols=1)

sns.countplot(data=df,x='type of meal',ax=axes[0])

sns.countplot(data=df,x='market segment type',ax=axes[1])

sns.countplot(data=df,x='booking status',ax=axes[2])

plt.tight_layout()

# %%
df['booking status'].value_counts() / df.shape[0] * 100
# Out:
# booking status
# Not_Canceled    67.234394
# Canceled        32.765606
# Name: count, dtype: float64

# %%
# Percentage of customers with market segment type either 'Online' , 'Offline'
percentage_online = df[df['market segment type'] == 'Online'].shape[0] / df.shape[0] * 100
percentage_online
# Out:
# 63.996141656331815

# %%
percentage_offline = df[df['market segment type'] == 'Offline'].shape[0] / df.shape[0] * 100
percentage_offline
# Out:
# 29.02301226402095

# %%
plt.bar(df['room type'].value_counts().index,df['room type'].value_counts())
plt.xticks(rotation=45)
plt.show()

# %%
fig , axes = plt.subplots(figsize=(12,6),ncols=3)

sns.countplot(data=df,x='car parking space',ax=axes[0])

sns.countplot(data=df,x='repeated',ax=axes[1])

sns.countplot(data=df,x='special requests',ax=axes[2])
# Out:
# <Axes: xlabel='special requests', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
segments = ['Online', 'Offline']
p_c_values = [p_online, p_offline]
p_not_c_values = [1 - p_online, 1 - p_offline]

# Setting up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Defining the position of the bars
x = np.arange(len(segments))
width = 0.35

# Plotting the bars
bars1 = ax.bar(x - width/2, p_c_values, width, label='P-C', color='blue')
bars2 = ax.bar(x + width/2, p_not_c_values, width, label='P-not-C', color='orange')

# Adding labels and title
ax.set_xlabel('Market Segment Type')
ax.set_ylabel('Probability')
ax.set_title('Probability Distribution for P-C and P-not-C')
ax.set_xticks(x)
ax.set_xticklabels(segments)
ax.legend()

# Adding value labels on the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords='offset points',
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

# Display the plot
plt.show()

# %%
# Calculate probability of 'Offline'
p_offline = df[df['market segment type'] == 'Offline'].shape[0] / df.shape[0]

# Calculate probability of not 'Offline'
p_not_offline = 1 - p_offline

print(f"P-Offline: {p_offline * 100}%")
print(f"P-not-Offline: {p_not_offline * 100}%")
# Out:
# P-Offline: 29.019099853926082%
# P-not-Offline: 70.98090014607392%

# %%
# Calculate probability of 'Online'
p_online = df[df['market segment type'] == 'Online'].shape[0] / df.shape[0]

# Calculate probability of not 'Online'
p_not_online = 1 - p_online

print(f"P-Online: {p_online * 100}%")
print(f"P-not-Online: {p_not_online * 100}%")
# Out:
# P-Online: 63.99966926659868%
# P-not-Online: 36.00033073340132%

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1.Both 'average price' & 'lead time' are right skewed
#
# 2.Target column have 67% Not Canceled & 32% Canceled values
#
# 3.The most type of room reserved was 'Room Type 1'.
#
# 4.'Offline' & ''Online cover about 93% values in market segment type
#
# 5.The mostly reserved meal type is 'Meal Type 1'
#
# 6.Majority of the reservations were made by people that were not repeated.
#
# 7.customer presence (P-C) and absence (P-not-C) in both 'Online' and 'Offline' segments reveal that the online segment has   a higher probability of customer presence

# %% [markdown]
# # Bivariate Analysis

# %%
df['Year'] = df['date of reservation'].dt.year
df['Month'] = df['date of reservation'].dt.month_name()
df['Day'] = df['date of reservation'].dt.day
df['Month_no'] = df['date of reservation'].dt.month

# %%
df.head()
# Out:
#    number of adults  number of children  number of weekend nights  \
# 0                 1                   1                         2
# 1                 1                   0                         1
# 2                 2                   1                         1
# 3                 1                   0                         0
# 4                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price  \
# ...

# %%
df['Year'].value_counts()
# Out:
# Year
# 2018    29767
# 2017     6516
# 2015        1
# 2016        1
# Name: count, dtype: int64

# %%
# Since there are only 1 value for 2015 and 2016 each so we will remove them because they can have a neagtive effect on our analysis.
temp_index = df[(df['Year']==2015) | (df['Year']==2016)].index
df.drop(index=temp_index,inplace=True)

# %%
df.groupby(['Year','booking status'])['Year'].count()
# Out:
# Year  booking status
# 2017  Canceled            962
#       Not_Canceled       5554
# 2018  Canceled          10926
#       Not_Canceled      18841
# Name: Year, dtype: int64

# %%
bkyear = df.pivot_table(index='Year',columns='booking status',values='Day',aggfunc='count')
bkyear
# Out:
# booking status  Canceled  Not_Canceled
# Year
# 2017                 962          5554
# 2018               10926         18841

# %%
sns.lineplot(x=[2017,2018],y=bkyear['Canceled'],label='Canceled')
sns.lineplot(x=[2017,2018],y=bkyear['Not_Canceled'],label='Not Canceled')
plt.title('Year wise Cancelation and No cancelation')
plt.grid()

# %%
fig , axes = plt.subplots(figsize=(10,5) ,ncols=2)

sns.barplot(data=df,y='lead time',x='booking status',ax=axes[0])

sns.barplot(data=df,y='average price',x='booking status',ax=axes[1])
# Out:
# <Axes: xlabel='booking status', ylabel='average price'>

# %%
sns.catplot(kind='count',data=df,x='market segment type',hue='booking status')
# Out:
# C:\Users\Madhuri\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df.pivot_table(index='Month',columns='booking status',values='Year',aggfunc='count'),cmap='PuRd')
# Out:
# <Axes: xlabel='booking status', ylabel='Month'>

# %%
sns.heatmap(df.pivot_table(index='Day',columns='booking status',values='Year',aggfunc='count'),cmap='PuRd')
# Out:
# <Axes: xlabel='booking status', ylabel='Day'>

# %%
sns.countplot(data=df,x='type of meal',hue='booking status')
# Out:
# <Axes: xlabel='type of meal', ylabel='count'>

# %%
sns.countplot(data=df,x='car parking space',hue='booking status')
# Out:
# <Axes: xlabel='car parking space', ylabel='count'>

# %%
pd.crosstab(df['market segment type'], df['booking status'])
# Out:
# booking status       Canceled  Not_Canceled
# market segment type
# Aviation                   37            88
# Complementary               0           391
# Corporate                 220          1797
# Offline                  3153          7376
# Online                   8478         14743

# %% [markdown]
# # Conclusions

# %% [markdown]
#  1.Most Cancelation are observed in 'August , September , October'.
#
# 2.Price increases with more no of people , special requests and car parking space.
#
# 3.Room type 1 and Meal type 1 is most frequent.
